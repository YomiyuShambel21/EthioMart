# %% [markdown]
# # **Task 2 : Label a Subset of Dataset in CoNLL Format**

# %%
# Import necessary libraries
import pandas as pd
import logging
import os, sys
import matplotlib.pyplot as plt
from matplotlib import font_manager
from collections import Counter
# Add the 'scripts' directory to the Python path for module imports
sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))
# Import data preprocessor class
from text_processor import AmharicTextPreprocessor
from labeler import AmharicNERLabeler

# Set max rows and columns to display
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# Configure logging
logging.basicConfig(level=logging.INFO, 
                    format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

logger.info("Imported libraries and configured logging.")
# Out:
# 2025-01-21 22:15:46,846 - INFO - Imported libraries and configured logging.

# %% [markdown]
# # Load the data

# %%
# Read the data
data = pd.read_csv('../data/clean_data.csv')
# Explore the first five rows
data.head()
# Out:
#        Channel Title Channel Username     ID  \
# 0  SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14839
# 1  SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14835
# 2  SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14832
# 3  SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14825
# 4  SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14815
#
#                                              Message  \
# 0  ለኮንዶሚኒየም ለጠባብ ቤቶች ገላግሌ የሆነ ከንፁህ የሲልከን ጥሬ እቃ የተ...
# 1  Baby romper   ከላዩ ፈር ውስጡ ኮተን የሆነ\n\n2000 birr\...
# 2  Chicco 5 in 1 mama bag\nኦሪጅናል ማቴሪያል\nበሳይዙ ትልቅ\...
# 3  aiebao HIP SEAT CARRIER\nምቹ ጠንካራ የልጆች ማዘያ\nበተለ...
# 4  Kids mat  \n\n4100 ብር\n\nSize 1.80*2m\n\nfree ...
#
#                         Date                  Media Path
# 0  2024-09-26 12:24:51+00:00  photos\@sinayelj_14839.jpg
# 1  2024-09-26 12:24:11+00:00  photos\@sinayelj_14835.jpg
# 2  2024-09-26 12:20:22+00:00  photos\@sinayelj_14832.jpg
# 3  2024-09-26 12:19:20+00:00  photos\@sinayelj_14825.jpg
# 4  2024-09-25 06:15:53+00:00  photos\@sinayelj_14815.jpg

# %% [markdown]
# # Preprocess text data

# %%
# Preprocess and tokenizes the amharic message
if __name__ == "__main__":
    # Amharic text sample
    amharic_text = "ሰላም እንዴት ነህ? እንኳን ደህና መጣህ።"

    preprocessor = AmharicTextPreprocessor()

    # Preprocess the text
    tokens = preprocessor.preprocess_dataframe(data, 'Message')
    display(tokens)
# Out:
#           Channel Title Channel Username     ID  \
# 0     SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14839
# 1     SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14835
# 2     SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14832
# 3     SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14825
# 4     SINA KIDS/ሲና ኪድስⓇ        @sinayelj  14815
# ...                 ...              ...    ...
# 1350  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    674
# 1351  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    640
# 1352  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    605
# 1353  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    598
# 1354  SINA KIDS/ሲና ኪድስⓇ        @sinayelj    182
#
#                                                 Message  \
# 0     ለኮንዶሚኒየም ለጠባብ ቤቶች ገላግሌ የሆነ ከንፁህ የሲልከን ጥሬ እቃ የተ...
# 1     Baby romper   ከላዩ ፈር ውስጡ ኮተን የሆነ\n\n2000 birr\...
# 2     Chicco 5 in 1 mama bag\nኦሪጅናል ማቴሪያል\nበሳይዙ ትልቅ\...
# 3     aiebao HIP SEAT CARRIER\nምቹ ጠንካራ የልጆች ማዘያ\nበተለ...
# 4     Kids mat  \n\n4100 ብር\n\nSize 1.80*2m\n\nfree ...
# ...                                                 ...
# 1350  ምቹ የልጆች ፖፖ የሶፍት ማስቀመጫ ያለው 1000ብር\nFree deliver...
# 1351  ለልጆች ምቹ እና ኮንፈርተብል ማት \nከላይ ማጫወቻ ያለዉ ከተፈለገ ማጫወ...
# 1352  Baby potty \nበባትሪ የሚሰራ ድምፅ ያለው\nየልጆች ፖፖ 899 ብር...
# 1353                 Baby potty\n0905707448\n0945097042
# 1354  ውድ የሲና ኪድስ ደምበኞች በድጋሚ ገብቷል \nየመዋኛ ገንዳ ትልቅ ሳይዝ ...
#
#                            Date                  Media Path  \
# 0     2024-09-26 12:24:51+00:00  photos\@sinayelj_14839.jpg
# 1     2024-09-26 12:24:11+00:00  photos\@sinayelj_14835.jpg
# 2     2024-09-26 12:20:22+00:00  photos\@sinayelj_14832.jpg
# 3     2024-09-26 12:19:20+00:00  photos\@sinayelj_14825.jpg
# 4     2024-09-25 06:15:53+00:00  photos\@sinayelj_14815.jpg
# ...                         ...                         ...
# 1350  2021-04-28 19:12:19+00:00    photos\@sinayelj_674.jpg
# 1351  2021-04-20 11:16:59+00:00    photos\@sinayelj_640.jpg
# 1352  2021-04-16 18:27:22+00:00    photos\@sinayelj_605.jpg
# 1353  2021-04-16 18:12:10+00:00    photos\@sinayelj_598.jpg
# 1354  2020-11-10 06:59:31+00:00    photos\@sinayelj_182.jpg
#
#                                    preprocessed_message
# 0     ለኮንዶሚኒየም ለጠባብ ቤቶች ገላግሌ የሆነ ከንፁህ የሲልከን ጥሬ እቃ የተ...
# 1     ከላዩ ፈር ውስጡ ኮተን የሆነ 2000 0909003864 0905707448 ...
# 2     5 1 ኦሪጅናል ማቴሪያል በሳይዙ ትልቅ 3200 ብር 0909003864 09...
# 3     ምቹ ጠንካራ የልጆች ማዘያ በተለይ ለወንድ ልጆች ፍሬያቸው እንዳይጎዳ ተደ...
# 4     4100 ብር 1802 0909003864 0905707448 እቃ ለማዘዝ ከስር...
# ...                                                 ...
# 1350  ምቹ የልጆች የሶፍት ማስቀመጫ ያለው 1000ብር 0905707448 09450...
# 1351  ለልጆች ምቹ እና ኮንፈርተብል ማት ከላይ ማጫወቻ ያለዉ ከተፈለገ ማጫወቻዉ...
# 1352  በባትሪ የሚሰራ ድምፅ ያለው የልጆች 899 ብር 0905707448 09450...
# 1353                              0905707448 0945097042
# 1354  ውድ የሲና ኪድስ ደምበኞች በድጋሚ ገብቷል የመዋኛ ገንዳ ትልቅ ሳይዝ የራ...
#
# [1355 rows x 7 columns]

# %%
# Drop NaN 
data.dropna(subset='Message', inplace=True)

# %%
# Ensure there are no NaN values in the preprocessed column
preprocessed_texts = tokens['preprocessed_message'].dropna().tolist()
data = pd.Series(preprocessed_texts).reset_index(name='message')

# %%
data.head()
# Out:
#    index                                            message
# 0      0  ለኮንዶሚኒየም ለጠባብ ቤቶች ገላግሌ የሆነ ከንፁህ የሲልከን ጥሬ እቃ የተ...
# 1      1  ከላዩ ፈር ውስጡ ኮተን የሆነ 2000 0909003864 0905707448 ...
# 2      2  5 1 ኦሪጅናል ማቴሪያል በሳይዙ ትልቅ 3200 ብር 0909003864 09...
# 3      3  ምቹ ጠንካራ የልጆች ማዘያ በተለይ ለወንድ ልጆች ፍሬያቸው እንዳይጎዳ ተደ...
# 4      4  4100 ብር 1802 0909003864 0905707448 እቃ ለማዘዝ ከስር...

# %% [markdown]
# # Label a Subset of Dataset in CoNLL Format

# %%
# Initialize the labeler

labeler = AmharicNERLabeler()

# Ensure there are no NaN values in the preprocessed column
preprocessed_texts = tokens['preprocessed_message'].dropna().tolist()
data = pd.Series(preprocessed_texts).reset_index(name='message')
# data = data.iloc[10:15]
data['Tokenized'] = data['message'].apply(lambda x: x.split())
# Label the tokens in the DataFrame
labeled_data = labeler.label_dataframe(data, 'Tokenized')


# Save to CoNLL format
labeler.save_conll_format(labeled_data, '../telegram_labeled_data.conll')

# %%
labeled_data.drop(columns=['index'], inplace=True)

# %%
labeled_data['message'].duplicated().sum()
# Out:
# 272
